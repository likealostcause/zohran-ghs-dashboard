# %% [markdown]
# # Accessibility
# This website details the school accessibility data:
# https://www.schools.nyc.gov/school-life/space-and-facilities/building-accessibility
#
# Accessibility data comes from this folder containing an XLSM:
# https://nycdoe.sharepoint.com/sites/BAP/Shared%20Documents/Forms/AllItems.aspx?id=%2Fsites%2FBAP%2FShared%20Documents%2FBuilding%20Accessibility%20Profile%20List&p=true&ga=1

# %%
# !pip3 install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: openpyxl in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import json
from openpyxl import load_workbook

# %%
from openpyxl import load_workbook

wb = load_workbook('../processed_data/Current_Building_Accessibility_Profile_List.xlsm', read_only=True)
ws = wb.active
data = ws.values

next(data)
next(data) # Skip the first and second row (title/description row)
columns = next(data)  # Third row is the actual header
df = pd.DataFrame(data, columns=columns)

wb.close()

# %%
#removing header data from top
df = df[2:]
#removing empty rows from bottom
df = df[:-2]
#removing hyperlink BAP URL column
df = df.drop('BAP URL', axis=1)
#removing empty columns
df = df.dropna(axis=1, how='all')

# %%
print("Duplicates found:", df.duplicated().sum())
# Out:
# Duplicates found: 0

# %%
df
# Out:
#      Geographical District Code        Borough Building Code Location Code  \
# 2                            07          Bronx          X040          X369
# 3                            07          Bronx          X065          X065
# 4                            07          Bronx          X065          X491
# 5                            07          Bronx          X139          X224
# 6                            07          Bronx          X139          X334
# ...                         ...            ...           ...           ...
# 1721                         31  Staten Island          R880          R037
# 1722                         31  Staten Island          R880          R076
# 1723                         31  Staten Island          R880          R080
# 1724                         31  Staten Island          R880          R903
# 1725                         31  Staten Island          R973          R373
#
#            School DBN                              School Name  \
# 2     07X369                   YOUNG LEADERS ELEMENTARY SCHOOL
# 3     07X065                      P.S. 065 MOTHER HALE ACADEMY
# 4     84X491                ACADEMIC LEADERSHIP CHARTER SCHOOL
# 5     07X224                                     P.S./I.S. 224
# 6     07X334               INTERNATIONAL COMMUNITY HIGH SCHOOL
# ...               ...                                      ...
# 1721  75R037              THE DAVID MARQUIS SCHOOL OF THE ARTS
# 1722  84R076                 BRIDGE PREPARATORY CHARTER SCHOOL
# 1723  31R080                    THE MICHAEL J. PETRIDES SCHOOL
# 1724  33R903           THE MODERN YOUTH APPRENTICESHIP PROGRAM
# 1725  75R373                                         P.S. R373
#
#                         Grades Served Pre-K              Address  \
# 2                          Elementary   Yes  468 EAST 140 STREET
# 3                          Elementary   Yes  677 EAST 141 STREET
# 4                                 K-8  None  677 EAST 141 STREET
# 5     Junior High-Intermediate-Middle  None     345 BROOK AVENUE
# 6                         High school  None     345 BROOK AVENUE
# ...                               ...   ...                  ...
# 1721                  K-12 all grades   Yes    715 OCEAN TERRACE
# 1722                       Elementary  None    715 OCEAN TERRACE
# 1723                  K-12 all grades   Yes    715 OCEAN TERRACE
# 1724                      High school  None    715 OCEAN TERRACE
# 1725                              K-8   Yes  91 HENDERSON AVENUE
#
#      Accessibility Description  \
# 2         Partially Accessible
# 3         Partially Accessible
# 4         Partially Accessible
# 5         Partially Accessible
# 6         Partially Accessible
# ...                        ...
# 1721      Partially Accessible
# 1722      Partially Accessible
# 1723      Partially Accessible
# 1724      Partially Accessible
# 1725          Fully Accessible
#
#                                            BAP Full URL
# 2     https://nycdoe.sharepoint.com/:w:/s/BAP/ETJ6jC...
# 3     https://nycdoe.sharepoint.com/:w:/s/BAP/ETqUxf...
# 4     https://nycdoe.sharepoint.com/:w:/s/BAP/ETqUxf...
# 5     https://nycdoe.sharepoint.com/:w:/s/BAP/ETyKqF...
# 6     https://nycdoe.sharepoint.com/:w:/s/BAP/ETyKqF...
# ...                                                 ...
# 1721  https://nycdoe.sharepoint.com/:w:/s/BAP/Eayjhi...
# 1722  https://nycdoe.sharepoint.com/:w:/s/BAP/Eayjhi...
# 1723  https://nycdoe.sharepoint.com/:w:/s/BAP/Eayjhi...
# 1724  https://nycdoe.sharepoint.com/:w:/s/BAP/Eayjhi...
# 1725  https://nycdoe.sharepoint.com/:w:/s/BAP/Eek5tS...
#
# [1724 rows x 11 columns]

# %%
len(df)
# Out:
# 1724

# %%
df.columns
# Out:
# Index(['Geographical District Code', 'Borough', 'Building Code',
#        'Location Code', 'School DBN', 'School Name', 'Grades Served', 'Pre-K',
#        'Address', 'Accessibility Description', 'BAP Full URL'],
#       dtype='object')

# %%
import geopandas as gpd
import json

# Read the GeoJSON file
gdf = gpd.read_file('../processed_data/school_points_with_lcgms.geojson')

# Basic inspection
print("Shape (rows, columns):", gdf.shape)
print("\nColumn names:")
print(gdf.columns.tolist())

print("\nData types:")
print(gdf.dtypes)

print("\nFirst few rows:")
print(gdf.head())

# Check the geometry type
print("\nGeometry types:")
print(gdf.geometry.type.unique())

# Check the coordinate reference system
print("\nCRS:", gdf.crs)

# Summary statistics for numeric columns
print("\nSummary statistics:")
print(gdf.describe())

# Check for missing values
print("\nMissing values:")
print(gdf.isnull().sum())
# Out:
# Shape (rows, columns): (1968, 41)
#
# Column names:
# ['ATS', 'Location Code', 'Location Name', 'Latitude', 'Longitude', 'ATS System Code', 'BEDS Number', 'Managed By Name', 'Location Type Description', 'Location Category Description', 'Grades', 'Grades Final', 'Open Date', 'Status Description', 'Building Code', 'Primary Address', 'City', 'State Code', 'Zip', 'Borough Block Lot', 'Census Tract', 'Community District', 'Council District', 'NTA', 'NTA_Name', 'Principal Name', 'Principal Title', 'Principal Phone Number', 'Fax Number', 'Geographical District Code', 'Administrative District Code', 'Administrative District Location Code', 'Administrative District Name', 'Community School Sup Name', 'HighSchool Network Location Code', 'HighSchool Network Name', 'HighSchool Network Superintendent', 'HighSchool Network Superintendent Email', 'BCO Location Code', 'in_LCGMS', 'geometry']
#
# Data types:
# ATS                                          object
# Location Code                                object
# Location Name                                object
# Latitude                                    float64
# Longitude                                   float64
# ATS System Code                              object
# BEDS Number                                 float64
# Managed By Name                              object
# Location Type Description                    object
# Location Category Description                object
# Grades                                       object
# Grades Final                                 object
# Open Date                                    object
# Status Description                           object
# Building Code                                object
# Primary Address                              object
# City                                         object
# State Code                                   object
# Zip                                         float64
# Borough Block Lot                           float64
# Census Tract                                float64
# Community District                          float64
# Council District                            float64
# NTA                                          object
# NTA_Name                                     object
# Principal Name                               object
# Principal Title                              object
# Principal Phone Number                       object
# Fax Number                                   object
# Geographical District Code                  float64
# Administrative District Code                float64
# Administrative District Location Code        object
# Administrative District Name                 object
# Community School Sup Name                    object
# HighSchool Network Location Code             object
# HighSchool Network Name                      object
# HighSchool Network Superintendent            object
# HighSchool Network Superintendent Email      object
# BCO Location Code                            object
# in_LCGMS                                       bool
# geometry                                   geometry
# dtype: object
#
# First few rows:
#       ATS Location Code                 Location Name   Latitude  Longitude  \
# 0  15K001          K001           P.S. 001 The Bergen  40.648959 -74.011420
# 1  17K002          K002  Parkside Preparatory Academy  40.656423 -73.951575
# 2  13K003          K003  P.S. 003 The Bedford Village  40.682311 -73.955219
# 3  75K004          K004                     P.S. K004  40.658500 -73.879276
# 4  16K005          K005    P.S. 005 Dr. Ronald McNair  40.685241 -73.921970
#
#   ATS System Code   BEDS Number Managed By Name Location Type Description  \
# 0          15K001  3.315000e+11             DOE          General Academic
# 1          17K002  3.317000e+11             DOE          General Academic
# 2          13K003  3.313000e+11             DOE          General Academic
# 3          75K004  3.075000e+11             DOE         Special Education
# 4          16K005  3.316000e+11             DOE          General Academic
#
#      Location Category Description  ... Administrative District Location Code  \
# 0                       Elementary  ...                                  K815
# 1  Junior High-Intermediate-Middle  ...                                  K817
# 2                       Elementary  ...                                  K813
# 3                       Elementary  ...                                  DA75
# 4                       Elementary  ...                                  K816
#
#    Administrative District Name Community School Sup Name  \
# 0  COMMUNITY SCHOOL DISTRICT 15           ALVAREZ, RAFAEL
# 1  COMMUNITY SCHOOL DISTRICT 17           SHENEAN LINDSAY
# 2  COMMUNITY SCHOOL DISTRICT 13               MEGHAN DUNN
# 3    CITYWIDE SPECIAL EDUCATION        LOUISSAINT, KETLER
# 4  COMMUNITY SCHOOL DISTRICT 16           FABAYO MCINTOSH
#
#   HighSchool Network Location Code HighSchool Network Name  \
# 0                             None                    None
# 1                             None                    None
# 2                             None                    None
# 3                             None                    None
# 4                             None                    None
#
#   HighSchool Network Superintendent HighSchool Network Superintendent Email  \
# 0                              None                                    None
# 1                              None                                    None
# 2                              None                                    None
# 3                              None                                    None
# 4                              None                                    None
#
#   BCO Location Code  in_LCGMS                          geometry
# 0              KFSN      True  POINT (-8238913.587 4960700.272)
# 1              KFSS      True   POINT (-8232251.672 4961795.46)
# 2              KFSN      True  POINT (-8232657.321 4965594.938)
# 3              D075      True  POINT (-8224203.385 4962100.238)
# 4              KFSN      True  POINT (-8228956.059 4966025.055)
#
# [5 rows x 41 columns]
#
# Geometry types:
# ['Point' None]
#
# CRS: EPSG:3857
#
# Summary statistics:
#           Latitude    Longitude   BEDS Number           Zip  \
# count  1950.000000  1950.000000  1.883000e+03   1901.000000
# mean     40.736288   -73.919864  3.279505e+11  10802.291952
# std       0.085765     0.080203  1.663653e+10    527.712862
# min      40.508300   -74.243950  3.075000e+11  10001.000000
# 25%      40.671879   -73.961581  3.207009e+11  10452.000000
# 50%      40.729078   -73.920141  3.314000e+11  11105.000000
# 75%      40.817966   -73.878270  3.332009e+11  11231.000000
# max      40.903275   -73.708617  8.000000e+11  11791.000000
#
#        Borough Block Lot   Census Tract  Community District  Council District  \
# count       1.899000e+03    1899.000000         1900.000000       1898.000000
# mean        2.696632e+09   35664.429200          275.757368         24.603267
# std         1.181948e+09   34531.661992          113.662910         14.437042
# min         0.000000e+00       1.000000            0.000000          0.000000
# 25%         2.026380e+09   11800.000000          203.000000         12.000000
# 50%         3.013750e+09   24400.000000          303.000000         24.000000
# 75%         4.002740e+09   46201.000000          401.000000         37.000000
# max         5.078980e+09  162100.000000          503.000000         51.000000
#
#        Geographical District Code  Administrative District Code
# count                 1901.000000                   1901.000000
# mean                    15.853235                     28.465544
# std                      9.303538                     27.084089
# min                      0.000000                      1.000000
# 25%                      8.000000                     10.000000
# 50%                     15.000000                     20.000000
# 75%                     24.000000                     30.000000
# max                     32.000000                     84.000000
#
# Missing values:
# ATS                                          18
# Location Code                                 0
# Location Name                                18
# Latitude                                     18
# Longitude                                    18
# ATS System Code                              67
# BEDS Number                                  85
# Managed By Name                              67
# Location Type Description                    67
# Location Category Description                67
# Grades                                       76
# Grades Final                                102
# Open Date                                    67
# Status Description                           67
# Building Code                                 0
# Primary Address                              67
# City                                         67
# State Code                                   67
# Zip                                          67
# Borough Block Lot                            69
# Census Tract                                 69
# Community District                           68
# Council District                             70
# NTA                                          97
# NTA_Name                                     97
# Principal Name                              115
# Principal Title                             115
# Principal Phone Number                      180
# Fax Number                                  235
# Geographical District Code                   67
# Administrative District Code                 67
# Administrative District Location Code       356
# Administrative District Name                502
# Community School Sup Name                   791
# HighSchool Network Location Code           1532
# HighSchool Network Name                    1532
# HighSchool Network Superintendent          1532
# HighSchool Network Superintendent Email    1532
# BCO Location Code                           356
# in_LCGMS                                      0
# geometry                                     18
# dtype: int64

# %%
school_with_bap = gdf.merge(
    df,
    on=['Location Code', 'Building Code'],
    how='left',
    suffixes=('', '_bap')
)
