# %%
import pandas as pd
import geopandas as gpd
import folium

pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Solar Readiness Assessment
#
# The solar readiness of each building represents the ability to host solar PV systems in their current condition. Buildings must be:
#
# 1. 10,000 square feet or more.
# 2. Roof that's 10 years old or newer.
# 3. Be in good structural condition.
#
# Read more at: https://www.nyc.gov/assets/dcas/downloads/pdf/energy/reportsandpublication/local24_2022.pdf

# %%
schools = pd.read_excel("../data/raw_data/DOE/School Locations/LCGMS/LCGMS_SchoolData_20251020_2055.xlsx")
solar_readiness = pd.read_csv("../data/raw_data/DCAS/solar_readiness/City_of_New_York_Municipal_Solar-Readiness_Assessment_(Local_Law_24_of_2016)_data_20251020.csv")

# %%
solar_readiness.query("Agency == 'DOE'").query("Site == 'R036'").T
# Out:
#                                                                                     256   \
# City Council District                                                                 51
# Agency                                                                               DOE
# Site                                                                                R036
# Address                                                                    255 Ionia Ave
# Borough                                                                    Staten Island
# Environmental Justice Area                                                            No
# Installation Date                                                                    NaN
# Installed or Estimated Capacity                                                      285
# Percentage of Max Peak Demand                                                     84.40%
# Estimated Annual Production                                                       313500
# Percentage of Annual Electricity Consumption                                    0.596915
# Estimated Annual Emissions Reduction                                           91 MT CO2
# Estimated Social Cost of Carbon Value                                            $12,866
# Estimated Annual Energy Savings                                                  $47,025
# Upfront Project Cost                                                                 NaN
# Financing Mechanism                                                                  NaN
# Status                                                                       In Progress
# Solar-Readiness Assessment                                                           NaN
# Total Gross Square Footage                                                           NaN
# Roof Condition                                                                       NaN
# Roof Age                                                                             NaN
# Other Sustaibility Projects                                                          NaN
# Year of Report                                                                      2022
# Data Current as of                                                            07/07/2022
# Postcode                                                                         10312.0
# Latitude                                                                       40.543083
# Longitude                                                                     -74.182299
# Community Board                                                                    503.0
# Census Tract                                                                     17005.0
# BIN                                                                            5107742.0
# BBL                                                                         5062620012.0
# NTA                                           Annadale-Huguenot-Prince's Bay-Eltingville
#
#                                                                                     511   \
# City Council District                                                                 51
# Agency                                                                               DOE
# Site                                                                                R036
# Address                                                                    255 Ionia Ave
# Borough                                                                    Staten Island
# Environmental Justice Area                                                            No
# Installation Date                                                                    NaN
# Installed or Estimated Capacity                                                      285
# Percentage of Max Peak Demand                                                        NaN
# Estimated Annual Production                                                       313500
# Percentage of Annual Electricity Consumption                                         NaN
# Estimated Annual Emissions Reduction                                           91 MT CO2
# Estimated Social Cost of Carbon Value                                                NaN
# Estimated Annual Energy Savings                                                      NaN
# Upfront Project Cost                                                                 NaN
# Financing Mechanism                                                                  NaN
# Status                                                                       Solar Ready
# Solar-Readiness Assessment                                                           Yes
# Total Gross Square Footage                                                    83,000 GSF
# Roof Condition                                                                      Good
# Roof Age                                                                    2 to 4 years
# Other Sustaibility Projects                                                           No
# Year of Report                                                                      2022
# Data Current as of                                                            07/07/2022
# Postcode                                                                         10312.0
# Latitude                                                                       40.543083
# Longitude                                                                     -74.182299
# Community Board                                                                    503.0
# Census Tract                                                                     17005.0
# BIN                                                                            5107742.0
# BBL                                                                         5062620012.0
# NTA                                           Annadale-Huguenot-Prince's Bay-Eltingville
#
#                                                                                     2352  \
# City Council District                                                                 51
# Agency                                                                               DOE
# Site                                                                                R036
# Address                                                                    255 Ionia Ave
# Borough                                                                    Staten Island
# Environmental Justice Area                                                             �
# Installation Date                                                                    NaN
# Installed or Estimated Capacity                                                285.00 kW
# Percentage of Max Peak Demand                                                       0.84
# Estimated Annual Production                                                  313,500 kWh
# Percentage of Annual Electricity Consumption                                         0.6
# Estimated Annual Emissions Reduction                                           91 MT CO2
# Estimated Social Cost of Carbon Value                                            $12,866
# Estimated Annual Energy Savings                                                  $47,025
# Upfront Project Cost                                                                 NaN
# Financing Mechanism                                                                  PPA
# Status                                                                       In Progress
# Solar-Readiness Assessment                                                           NaN
# Total Gross Square Footage                                                           NaN
# Roof Condition                                                                       NaN
# Roof Age                                                                             NaN
# Other Sustaibility Projects                                                          NaN
# Year of Report                                                                      2020
# Data Current as of                                                            06/14/2021
# Postcode                                                                         10312.0
# Latitude                                                                       40.543083
# Longitude                                                                     -74.182299
# Community Board                                                                    503.0
# Census Tract                                                                     17005.0
# BIN                                                                            5107742.0
# BBL                                                                         5062620012.0
# NTA                                           Annadale-Huguenot-Prince's Bay-Eltingville
#
#                                                                                     2604
# City Council District                                                                 51
# Agency                                                                               DOE
# Site                                                                                R036
# Address                                                                    255 Ionia Ave
# Borough                                                                    Staten Island
# Environmental Justice Area                                                             �
# Installation Date                                                                    NaN
# Installed or Estimated Capacity                                                285.00 kW
# Percentage of Max Peak Demand                                                313,500 kWh
# Estimated Annual Production                                                          NaN
# Percentage of Annual Electricity Consumption                                         NaN
# Estimated Annual Emissions Reduction                                           91 MT CO2
# Estimated Social Cost of Carbon Value                                                NaN
# Estimated Annual Energy Savings                                                      NaN
# Upfront Project Cost                                                                 NaN
# Financing Mechanism                                                                  NaN
# Status                                                                       Solar-Ready
# Solar-Readiness Assessment                                                           Yes
# Total Gross Square Footage                                                    83,000 GSF
# Roof Condition                                                                      Good
# Roof Age                                                                    2 to 4 years
# Other Sustaibility Projects                                                           No
# Year of Report                                                                      2020
# Data Current as of                                                            06/14/2021
# Postcode                                                                         10312.0
# Latitude                                                                       40.543083
# Longitude                                                                     -74.182299
# Community Board                                                                    503.0
# Census Tract                                                                     17005.0
# BIN                                                                            5107742.0
# BBL                                                                         5062620012.0
# NTA                                           Annadale-Huguenot-Prince's Bay-Eltingville

# %%
# sizeable chunk (4.2k from solar readiness, 1.9k from schools, only 1.5k left. Since we only survey buildings above 100k sqft, this seems not unreasonable.)
# we use building site, I feel like this isn't perfect, b/c maybe two buildings share the same site, but for now I can't think of a better way. 
df = solar_readiness.merge(schools, left_on="Site", right_on="Location Code", how='inner')
print(len(df), len(solar_readiness), len(schools))
print(solar_readiness.groupby("Site").size().describe())
print(schools.groupby("Location Code").size().describe())
# Out:
# 1557 4268 1901
# count    2255.000000
# mean        1.892683
# std         0.527012
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         2.000000
# max        18.000000
# dtype: float64
# count    1901.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# dtype: float64

# %%
gdf = gpd.GeoDataFrame(df[[
    # solar readiness columns
    "Site", 
    "Address", 
    "Borough", 
    "Status", 
    "Solar-Readiness Assessment",
    "Latitude", 
    "Longitude", 
    "BIN", 
    "BBL", 
    "Total Gross Square Footage",
    "Roof Condition",
    "Roof Age", 
    "Estimated Annual Emissions Reduction", 
    "Estimated Social Cost of Carbon Value", 
    "Estimated Annual Energy Savings",

    # school points columns
    "Location Name",
    "BEDS Number",
]].assign(Status=lambda df: df.Status.str.replace("-", " ")).dropna(subset=["Latitude", "Longitude"])) # post processing
gdf.to_csv("../data/solar_readiness/solar_readiness_per_site.csv")

# %%
# !rm -f ../data/solar_readiness/solar_readiness_per_site.geojson
gdf.to_file("../data/solar_readiness/solar_readiness_per_site.geojson", driver="GeoJson")

# %%
# Weirdly, Status == 'Solar Ready' is not the same as Solar-Readiness Assessment 'Yes'
# Maybe worth digging into if we're specifically trying to install solar panels.
print(gdf.assign(Status=lambda df: df.Status.str.replace("-", " ")).groupby(['Status', 'Solar-Readiness Assessment']).size())
gdf.query("Status == 'Solar Ready' and `Solar-Readiness Assessment` == 'No'").head().T
# Out:
# Status           Solar-Readiness Assessment
# Not Solar Ready  No                            1126
#                  Yes                             41
# Solar Ready      No                             130
#                  Yes                             24
# dtype: int64
#                                                                                     112  \
# Site                                                                               M520
# Address                                                                    411 Pearl St
# Borough                                                                       Manhattan
# Status                                                                      Solar Ready
# Solar-Readiness Assessment                                                           No
# Latitude                                                                      40.711442
# Longitude                                                                    -74.000851
# BIN                                                                           1001388.0
# BBL                                                                        1001130100.0
# Total Gross Square Footage                                                  300,000 GSF
# Roof Condition                                                    Between Good and Fair
# Roof Age                                                                   5 to 9 years
# Estimated Annual Emissions Reduction                                           9 MT CO2
# Estimated Social Cost of Carbon Value                                               NaN
# Estimated Annual Energy Savings                                                     NaN
# Location Name                          Murry Bergtraum High School for Business Careers
# BEDS Number                                                              310200011520.0
#
#                                                            113  \
# Site                                                      M114
# Address                                       331 East 91st St
# Borough                                              Manhattan
# Status                                             Solar Ready
# Solar-Readiness Assessment                                  No
# Latitude                                             40.780706
# Longitude                                           -73.948553
# BIN                                                  1081267.0
# BBL                                               1015540032.0
# Total Gross Square Footage                          48,000 GSF
# Roof Condition                           Between Good and Fair
# Roof Age                                        10 to 14 years
# Estimated Annual Emissions Reduction                  7 MT CO2
# Estimated Social Cost of Carbon Value                      NaN
# Estimated Annual Energy Savings                            NaN
# Location Name                          East Side Middle School
# BEDS Number                                     310200010114.0
#
#                                                                 114  \
# Site                                                           M183
# Address                                              419 East 66 St
# Borough                                                   Manhattan
# Status                                                  Solar Ready
# Solar-Readiness Assessment                                       No
# Latitude                                                  40.763736
# Longitude                                                 -73.95815
# BIN                                                       1045569.0
# BBL                                                    1014610007.0
# Total Gross Square Footage                               58,800 GSF
# Roof Condition                                                 Good
# Roof Age                                                  < 2 years
# Estimated Annual Emissions Reduction                      13 MT CO2
# Estimated Social Cost of Carbon Value                           NaN
# Estimated Annual Energy Savings                                 NaN
# Location Name                          P.S. 183 Robert L. Stevenson
# BEDS Number                                          310200010183.0
#
#                                                                                115  \
# Site                                                                          M191
# Address                                                             210 West 61 St
# Borough                                                                  Manhattan
# Status                                                                 Solar Ready
# Solar-Readiness Assessment                                                      No
# Latitude                                                                 40.771925
# Longitude                                                               -73.987328
# BIN                                                                      1030320.0
# BBL                                                                   1011520029.0
# Total Gross Square Footage                                              75,000 GSF
# Roof Condition                                               Between Good and Fair
# Roof Age                                                              5 to 9 years
# Estimated Annual Emissions Reduction                                     32 MT CO2
# Estimated Social Cost of Carbon Value                                          NaN
# Estimated Annual Energy Savings                                                NaN
# Location Name                          The Riverside School for Makers and Artists
# BEDS Number                                                         310300010191.0
#
#                                                                                      116
# Site                                                                                M485
# Address                                                                100 Amsterdam Ave
# Borough                                                                        Manhattan
# Status                                                                       Solar Ready
# Solar-Readiness Assessment                                                            No
# Latitude                                                                       40.773629
# Longitude                                                                     -73.985273
# BIN                                                                            1030341.0
# BBL                                                                         1011560030.0
# Total Gross Square Footage                                                   388,000 GSF
# Roof Condition                                                                      Good
# Roof Age                                                                    5 to 9 years
# Estimated Annual Emissions Reduction                                           49 MT CO2
# Estimated Social Cost of Carbon Value                                                NaN
# Estimated Annual Energy Savings                                                      NaN
# Location Name                          Fiorello H. LaGuardia High School of Music & A...
# BEDS Number                                                               310300011485.0

# %%
m = folium.Map(location=[40.7128, -74.0060], zoom_start=11)  # pick a suitable center

for readiness, sub in gdf.groupby("Solar-Readiness Assessment"):
    fg = folium.FeatureGroup(name=f"{readiness} ({len(sub)})", show=True)
    for _, r in sub.iterrows():
        folium.CircleMarker(
            location=[r["Latitude"], r["Longitude"]],
            radius=2,
            color="red" if readiness == 'No' else "green",
            weight=1,
            fill=True,
            fill_opacity=0.3 if readiness == 'No' else 0.8,
            popup=folium.Popup(f"<b>{r['Location Name']}</b><br>Roof Age: {r['Roof Age']}<br>Roof Condition: {r['Roof Condition']}<br>Est. Emmissions Reduction: {r['Estimated Annual Emissions Reduction']}", max_width=250),
            tooltip=r["Location Name"],
        ).add_to(fg)
    fg.add_to(m)

folium.LayerControl(collapsed=False).add_to(m)
