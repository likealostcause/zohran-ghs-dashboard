# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## 2022 Solar Readiness Assessment
#
# The solar readiness of each building represents the ability to host solar PV systems in their current condition. Buildings must be:
#
# 1. 10,000 square feet or more.
# 2. Roof that's 10 years old or newer.
# 3. Be in good structural condition.
#
# Read more at: https://www.nyc.gov/assets/dcas/downloads/pdf/energy/reportsandpublication/local24_2022.pdf

# %%
schools = gpd.read_file("../data/processed_data/school_points_with_lcgms.geojson")
ll24_2022 = pd.read_csv("../data/raw_data/DCAS/City_of_New_York_Municipal_Solar-Readiness_Assessment_(Local_Law_24_of_2016)_data_20251117.csv")

# Once we filter down to DOE sites and deduplicate to most recent report, only 1,094 schools remain
ll24_2022_doe = ll24_2022[ll24_2022['Agency']=='DOE']
ll24_2022_doe = ll24_2022_doe.sort_values(by='Year of Report', ascending=False).drop_duplicates(subset=['Site'])
# Clean up "site" field to improve matches to school building codes
pd.set_option('display.max_columns', None)
print('unique sites in solar readiness data: ', ll24_2022_doe['Site'].nunique())
print('Sites that join to schools before cleaning:', len(ll24_2022_doe[ll24_2022_doe['Site'].isin(schools['Building Code'])]))

# Did some manual review to find the right Building Code in the following Sites that had more than one valid-looking building code:
site_building_code_corrections = {
    'K134- K849, K839 CAMPUS: K849 (MAIN BUILDING)': 'K849',
    'K077 (K902 ANNEX)': 'K902',
    'M035 (M058)': 'M058',
    'K293 (K497)': 'K293',
    'K724 (K500)': 'K500',
    'Q825/Q125': 'Q125'
}
# Replace the sites with multiple codes with the correct building code, then extract the building code from the rest
ll24_2022_doe['Site'] = ll24_2022_doe['Site'].replace(site_building_code_corrections).str.extract(r'([LKMQRX]\d{3})')
print('Sites that join to schools after cleaning:', len(ll24_2022_doe[ll24_2022_doe['Site'].isin(schools['Building Code'])]))
# Drop duplicates again after cleaning up Site field
ll24_2022_doe = ll24_2022_doe.sort_values(by='Year of Report', ascending=False).drop_duplicates(subset=['Site'])
# Clean up various cols a bit
ll24_2022_doe['Status'] = ll24_2022_doe['Status'].str.replace('-', ' ')
ll24_2022_doe['Installed or Estimated Capacity'] = pd.to_numeric(ll24_2022_doe['Installed or Estimated Capacity'])
ll24_2022_doe['Estimated Annual Production'] = pd.to_numeric(ll24_2022_doe['Estimated Annual Production'])

# %%
# Remove unneeded columns
ll24_2022_essential_cols = [
    'Site',
    'Year of Report',
    'Installed or Estimated Capacity',
    'Status', 
    'Solar-Readiness Assessment',
    'Percentage of Max Peak Demand',
    'Estimated Annual Production',
    'Percentage of Annual Electricity Consumption',
    'Estimated Annual Emissions Reduction',
    'Estimated Annual Energy Savings',
    'Upfront Project Cost',
    'Total Gross Square Footage',
    'Roof Condition',
    'Roof Age',
    'Other Sustaibility Projects'
]
ll24_2022_doe = ll24_2022_doe[ll24_2022_essential_cols].reset_index(drop=True)

# %% [markdown]
# ## 2024 Solar Readiness Assessment
#
# NOTE: NYC didn't put this on Open Data so had to manually extract tables from the PDF available here: https://www.nyc.gov/assets/dcas/downloads/pdf/energy/reportsandpublication/local-law-24-fy2024-report.pdf.
#
# See the script `extract_ll24_fy2024_pdf.py` for how this was done.

# %%
ll24_fy2024 = pd.read_csv("../data/raw_data/DCAS/local-law-24-fy2024-report.csv")
ll24_fy2024_doe = ll24_fy2024[ll24_fy2024['Agency'] == 'DOE'].copy()
# Match the formatting of the 2022 NYC Open Data dataset
ll24_fy2024_doe['Year of Report'] = 2024

# %% [markdown]
# ### Clean `Site` field to improve matches to school building codes

# %%
# School building Q361 (The CIVIC School of Bayside Hills) shows up twice in the solar readiness data, both not solar ready, but one as "Q361" and one as "Q361 (Main Building)"
# Going to drop the record that is not the main building to avoid join complications
ll24_fy2024_doe = ll24_fy2024_doe[ll24_fy2024_doe['Site']!='Q361'].copy()

print('unique sites in solar readiness data: ', ll24_fy2024_doe['Site'].nunique())
print('Sites that join to schools before cleaning:', ll24_fy2024_doe['Site'].drop_duplicates().isin(schools['Building Code']).sum())
ll24_fy2024_doe['Site_original'] = ll24_fy2024_doe['Site']
# NOTE: order matters here: has to be tandem and campus first, and then only after those 2 are done we coalesce with the general building code regex
# The below is vibe code that takes something like "K721, K128 Tandem" and turns it into two rows with K721 and K128 as the Site, so we can join to schools on building code easily
pattern_tandem = r'([LKMQRX]\d{3}),\s*([LKMQRX]\d{3})\s+Tandem'
# rows that match "... , ... Tandem"
mask_tandem = ll24_fy2024_doe['Site'].str.contains(pattern_tandem, regex=True, na=False)
# two capture groups -> columns [0, 1]
pairs = ll24_fy2024_doe.loc[mask_tandem, 'Site'].str.extract(pattern_tandem)
# flatten both groups to one code per row index (duplicates index)
codes = pairs.stack().rename('Site').reset_index(level=1, drop=True)
# duplicate original rows using duplicated index, then assign extracted code
tandem_expanded = ll24_fy2024_doe.loc[codes.index].copy()
tandem_expanded['Site'] = codes.to_numpy()
# keep all non-tandem rows + expanded tandem rows
ll24_fy2024_doe = pd.concat(
    [ll24_fy2024_doe.loc[~mask_tandem], tandem_expanded],
    ignore_index=True
)

ll24_fy2024_doe['Site'] = ll24_fy2024_doe['Site'].replace(
    # One-off replace for record that isn't captured by the regex for "Campus" or "Tandem"
    {'R460, R461: R460': 'R460'}
    ).str.extract(
        # It looks like having "Campus: XXXX" in the Site field indicates building code AFAICT
        r'Campus: ([LKMQRX]\d{3})'
        ).combine_first(ll24_fy2024_doe['Site'].str.extract(r'([LKMQRX]\d{3})'))

# Drop records with NULL site
ll24_fy2024_doe = ll24_fy2024_doe[ll24_fy2024_doe['Site'].notna()].copy()

print('Unique sites found in schools building codes after cleaning Site field:', ll24_fy2024_doe['Site'].drop_duplicates().isin(schools['Building Code']).sum())

# %% [markdown]
# ### Deduplicate `Site` field
#
# The PDF erroneously has many "Solar Ready" records duplicated in the "Not Solar Ready" section

# %%
# Clean up the status field so that the "Solar-Ready" (from the Not Solar Ready section) vs "Solar Ready" (from the Solar Ready section) status values are consistent
ll24_fy2024_doe['2024 Solar-Ready Status'] = ll24_fy2024_doe['2024 Solar-Ready Status'].str.replace('-', ' ')

# There is one duplicate Site that has conflicting status: X445, which has a record for both "Completed" and "In Progress". 
ll24_fy2024_doe.loc[
    ll24_fy2024_doe.groupby('Site')['2024 Solar-Ready Status'].transform('nunique') > 1,
    :
]

# %%
# Going to keep the "In Progress" record and drop the "Completed" record, since the "In Progress" project is significantly larger than "Completed" one (i.e. 33.60 kW completed vs 547 kW in progress).
ll24_fy2024_doe = ll24_fy2024_doe[~((ll24_fy2024_doe['Site']=='X445') & (ll24_fy2024_doe['2024 Solar-Ready Status']== 'Completed'))].copy()

# Check that there are no conflicts in the actual status for duplicated sites after taking care of the one conflict with X445
assert not (ll24_fy2024_doe.groupby('Site')['2024 Solar-Ready Status'].transform('nunique') > 1).any()
# Check that all remaining duplicates are only from the "Not Solar Ready" and "Solar Ready Projects" appendices, to ensure the next step of sorting values on appendix works
assert ll24_fy2024_doe[ll24_fy2024_doe['Site'].duplicated(keep=False) & ll24_fy2024_doe['Site'].notna()].sort_values('Site')['Appendix Section'].unique().tolist() == ['Not Solar Ready', 'Solar Ready Projects']

# %%
# Combine records with duplicate sites. Looks like it's happening bc of showing up in both the "Not Solar Ready" and "Solar Ready" sections of the report.
# There are 424 records representing 211 unique sites that appear in both the "Solar Ready" and "Not Solar Ready" sections of the report. We should combine these records to have one record per site, since the "Solar Ready" vs "Not Solar Ready" status is really just a snapshot in time and having both records for the same site is redundant and confusing.
cols_from_not_solar_ready = [
    'Total Gross Square Footage',
    'Roof Condition',
    'Roof Age',
    'Other Sustainability Projects'
]
# Fill forward from the "Not Solar Ready" section to the "Solar Ready"  to get the few columns that are only in the "Not Solar Ready" section into the "Solar Ready" records
ll24_fy2024_doe.loc[:, cols_from_not_solar_ready] = ll24_fy2024_doe.sort_values('Appendix Section').groupby('Site')[cols_from_not_solar_ready].transform('ffill')
# Drop the site duplicates that are "Solar Ready" but from the "Not Solar Ready" section of the PDF now that we've filled in data where possible
ll24_fy2024_doe = ll24_fy2024_doe.sort_values('Appendix Section').drop_duplicates(subset=['Site'], keep='last')
assert len(ll24_fy2024_doe[ll24_fy2024_doe['Site'].duplicated(keep=False)].sort_values(['Site', 'Appendix Section'])) == 0

# %% [markdown]
# ### Clean Column values and names

# %%
# Remove units from the values of the data and put in column names instead
ll24_fy2024_doe['Capacity'] = pd.to_numeric(ll24_fy2024_doe['Capacity'].str.replace('kW|,', '', regex=True))
ll24_fy2024_doe['Percentage of Max Peak Demand'] = pd.to_numeric(ll24_fy2024_doe['Percentage of Max Peak Demand'].str.replace('%', '', regex=True))
ll24_fy2024_doe['Estimated Annual Production'] = pd.to_numeric(ll24_fy2024_doe['Estimated Annual Production'].str.replace('kWh|,', '', regex=True))
ll24_fy2024_doe['Percentage of Annual Electricity Consumption'] = pd.to_numeric(ll24_fy2024_doe['Percentage of Annual Electricity Consumption'].str.replace('%', '', regex=True))   
ll24_fy2024_doe['Estimated Annual Emissions Reduction'] = pd.to_numeric(ll24_fy2024_doe['Estimated Annual Emissions Reduction'].str.replace('MT CO2|,', '', regex=True))
ll24_fy2024_doe['Estimated Social Cost of Carbon Value'] = pd.to_numeric(ll24_fy2024_doe['Estimated Social Cost of Carbon Value'].str.replace(r'\$|,', '', regex=True))
ll24_fy2024_doe['Estimated Annual Energy Savings'] = pd.to_numeric(ll24_fy2024_doe['Estimated Annual Energy Savings'].str.replace(r'\$|,', '', regex=True))
ll24_fy2024_doe['Upfront Project Cost'] = pd.to_numeric(ll24_fy2024_doe['Upfront Project Cost'].str.replace(r'\$|,', '', regex=True))

rename_cols = {
    'Capacity': 'Capacity (kW)',
    'Estimated Annual Production': 'Estimated Annual Production (kWh)',
    'Estimated Annual Emissions Reduction': 'Estimated Annual Emissions Reduction (MT CO2)',
    '2024 Solar-Ready Status': 'Status'
}
ll24_fy2024_doe.rename(columns=rename_cols, inplace=True)

# %%
# Remove unnecessary columns
cols_to_remove = [
    'Source PDF Page', 
    'Appendix Section',
    'City Council District',
    'Agency',
    'Address',
    'Borough',
    'Disadvantaged Community',
    'Site_original',
    'Year of Report'
]
ll24_fy2024_doe.drop(columns=cols_to_remove, inplace=True)

# %% [markdown]
# Compare 2022 to 2024

# %%
# Find how many schools we can match from each
print('Sites from 2022 that join to schools after cleaning:', ll24_2022_doe['Site'].isin(schools['Building Code']).sum())
print('Sites from 2024 that join to schools after cleaning:', ll24_fy2024_doe['Site'].isin(schools['Building Code']).sum())

# %%
# Simple view of status transitions: 2022 -> 2024
import matplotlib.pyplot as plt

normalize = lambda s: s.astype('string').str.strip().str.lower().str.replace(r'\s+', ' ', regex=True)

compare = (
    ll24_2022_doe[['Site', 'Status']].drop_duplicates('Site')
    .assign(Status=lambda d: normalize(d['Status']))
    .rename(columns={'Status': 'Status_2022'})
    .merge(
        ll24_fy2024_doe[['Site', 'Status']].drop_duplicates('Site')
        .assign(Status=lambda d: normalize(d['Status']))
        .rename(columns={'Status': 'Status_2024'}),
        on='Site',
        how='inner'
    )
)

# All transitions (including unchanged)
transitions_all = (
    compare.value_counts(['Status_2022', 'Status_2024'])
    .rename('count')
    .reset_index()
    .sort_values('count', ascending=False)
)

changed = transitions_all[transitions_all['Status_2022'] != transitions_all['Status_2024']].copy()
same = transitions_all[transitions_all['Status_2022'] == transitions_all['Status_2024']].copy()

print(f'Overlapping sites: {len(compare)}')
print(f'Sites with changed status: {int(changed['count'].sum())}')
print(f'Sites that stayed the same: {int(same['count'].sum())}')

print('\nMost common status changes:')
display(changed.head(10))

print('\nMost common statuses that stayed the same:')
display(same.head(10))

# One clean chart for top transitions (changed + unchanged)
top = transitions_all.head(12).iloc[::-1].copy()
top['Transition'] = top['Status_2022'] + ' -> ' + top['Status_2024']
top['Stayed same?'] = top['Status_2022'] == top['Status_2024']
top['color'] = top['Stayed same?'].map({True: '#7a7a7a', False: '#2a9d8f'})

ax = top.plot.barh(x='Transition', y='count', legend=False, figsize=(10, 6), color=top['color'])
ax.set_title('Top Status Transitions (2022 -> 2024)')
ax.set_xlabel('Number of Sites')
ax.set_ylabel('')
plt.tight_layout()
plt.show()

# %%
# 2024 status snapshot
import matplotlib.pyplot as plt

status_2024_counts = (
    ll24_fy2024_doe['Status']
    .astype('string')
    .str.strip()
    .str.lower()
    .str.replace(r'\s+', ' ', regex=True)
    .value_counts()
    .rename_axis('Status_2024')
    .reset_index(name='count')
)

display(status_2024_counts)

plot_df = status_2024_counts.iloc[::-1]
ax = plot_df.plot.barh(x='Status_2024', y='count', legend=False, figsize=(8, 4), color='#e76f51')
ax.set_title('Current 2024 Status Distribution')
ax.set_xlabel('Number of Sites')
ax.set_ylabel('')
plt.tight_layout()
plt.show()

# %%
# TODO: analyze financing mechanisms and costs of completed projects

# %% [markdown]
# # Export Data

# %%
ll24_2022_doe.to_csv("../data/processed_data/solar_readiness_assessment_doe_buildings_2022.csv", index=False)
ll24_fy2024_doe.to_csv("../data/processed_data/solar_readiness_assessment_doe_buildings_2024.csv", index=False)
